# %%
import pickle
import pandas
from vocab_teacher.vocab_teacher import Session

# %%
session_file = "session\martin_german.pse" 
session = pickle.load(open(session_file, "rb"))

# %%
session

# %%
session.df_session
# Out:
#          word  rounds_last_met1  words_last_met1  time_last_met1  \
# 0         ich               142              100    1.677702e+09
# 1         sie               142              100    1.677702e+09
# 2         das               142              100    1.677702e+09
# 3         ist               142              100    1.677702e+09
# 4          du               142              100    1.677702e+09
# ..        ...               ...              ...             ...
# 495  gefallen               142              100    1.677702e+09
# 496   stunden               142              100    1.677702e+09
# 497      herz               142              100    1.677702e+09
# 498     wohin               142              100    1.677702e+09
# 499   trinken               142              100    1.677702e+09
#
#      res_last_met1  rounds_last_met2  words_last_met2  time_last_met2  \
# 0            False               142              100    1.677702e+09
# ...

# %%
session.df_session.loc[session.df_session["word"] == 'ich'][f"rounds_last_met{1}"] = 0

# %%
session.df_session.loc[session.df_session["word"] == 'ich',f"rounds_last_met{1}"] = 0

# %%
session.df_session.loc[session.df_session["word"] == 'ich',f"rounds_last_met{1}"]
# Out:
# 0    0
# Name: rounds_last_met1, dtype: int64
